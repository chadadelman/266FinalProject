# %%
#Creates all_text_dict, a master database of raw text files (scenes and sonnets)
# %store -r all_scenes
# %store -r sonnets_dict
# %store -r jonson_scene_dict


all_text_dict={}
all_text_dict.update(all_scenes)
all_text_dict.update(sonnets_dict)
all_text_dict.update(jonson_scene_dict)

# %store all_text_dict
# Out:
# Stored 'all_text_dict' (dict)

# %%
#Just for checking
key_list = list(all_text_dict.keys())
value_list = list(all_text_dict.values())
print(key_list[701:710])
# Out:
# ['Troilus_and_Cressida-ACT V-Scene I-The Grecian camp. Before the tent of Achilles.', 'Troilus_and_Cressida-ACT V-Scene II-The Grecian camp. Before Calchas’ tent.', 'Troilus_and_Cressida-ACT V-Scene III-Troy. Before Priam’s palace.', 'Troilus_and_Cressida-ACT V-Scene IV-The plain between Troy and the Grecian camp.', 'Troilus_and_Cressida-ACT V-Scene V-Another part of the plain.', 'Troilus_and_Cressida-ACT V-Scene VI-Another part of the plain.', 'Troilus_and_Cressida-ACT V-Scene VII-Another part of the plain.', 'Troilus_and_Cressida-ACT V-Scene VIII-Another part of the plain.', 'Troilus_and_Cressida-ACT V-Scene IX-Another part of the plain.']

# %%
for k in all_text_dict.keys():
    if "MacBeth" in k:
        print(k)
# Out:
# MacBeth-ACT I-Scene I-An open Place.
# MacBeth-ACT I-Scene II-A Camp near Forres.
# MacBeth-ACT I-Scene III-A heath.
# MacBeth-ACT I-Scene IV-Forres. A Room in the Palace.
# MacBeth-ACT I-Scene V-Inverness. A Room in Macbeth’s Castle.
# MacBeth-ACT I-Scene VI-The same. Before the Castle.
# MacBeth-ACT I-Scene VII-The same. A Lobby in the Castle.
# MacBeth-ACT II-Scene I-Inverness. Court within the Castle.
# MacBeth-ACT II-Scene II-The same.
# MacBeth-ACT II-Scene III-The same.
# MacBeth-ACT II-Scene IV-The same. Without the Castle.
# MacBeth-ACT III-Scene I-Forres. A Room in the Palace.
# MacBeth-ACT III-Scene II-The same. Another Room in the Palace.
# MacBeth-ACT III-Scene III-The same. A Park or Lawn, with a gate leading to the Palace.
# MacBeth-ACT III-Scene IV-The same. A Room of state in the Palace.
# MacBeth-ACT III-Scene V-The heath.
# MacBeth-ACT III-Scene VI-Forres. A Room in the Palace.
# MacBeth-ACT IV-Scene I-A dark Cave. In the middle, a Cauldron Boiling.
# MacBeth-ACT IV-Scene II-Fife. A Room in Macduff’s Castle.
# MacBeth-ACT IV-Scene III-England. Before the King’s Palace.
# MacBeth-ACT V-Scene I-Dunsinane. A Room in the Castle.
# MacBeth-ACT V-Scene II-The Country near Dunsinane.
# MacBeth-ACT V-Scene III-Dunsinane. A Room in the Castle.
# MacBeth-ACT V-Scene IV-Country near Dunsinane: a Wood in view.
# MacBeth-ACT V-Scene V-Dunsinane. Within the castle.
# MacBeth-ACT V-Scene VI-The same. A Plain before the Castle.
# MacBeth-ACT V-Scene VII-The same. Another part of the Plain.
# MacBeth-ACT V-Scene VIII-The same. Another part of the field.
