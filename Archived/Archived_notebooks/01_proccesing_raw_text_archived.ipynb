# %% [markdown]
# ## Create Text_Dict dictionary
# This file will convert the raw text files for the different text files into a dictinary where each element is {"scene","text"} for example Text_Dict["much_ado_about_nothing_act2scene2"]="Enter Don John and Borach...". This dictinary will later be combined with a dictionary that also contains the summarization of the article.

# %%
#Set up
raw_text_location = "../data/raw/Text/"

#Importing raw text into strings
def read_raw_text(file_name):
    with open(raw_text_location+file_name, "r") as f:
        contents = f.read()
    return contents

# %%
#import raw text and store in variabels
hamlet_raw_text = read_raw_text("Hamlet.txt") 
Julius_Caesar_raw_text = read_raw_text("Julius_Caesar.txt")
Macbeth_raw_text = read_raw_text("Macbeth.txt") 
Much_Ado_About_Nothing_raw_text = read_raw_text("Much_Ado_About_Nothing.txt")

Othello_raw_text = read_raw_text("Othello.txt")
Romeo_and_Juliet_raw_text = read_raw_text("Romeo_and_Juliet.txt")
The_Taming_Of_The_Shrew_raw_text = read_raw_text("The_Taming_Of_The_Shrew.txt")
Twelfth_Night_raw_text = read_raw_text("Twelfth_Night.txt")

King_Lear_raw_text = read_raw_text("King_Lear.txt")
The_Winters_Tale_raw_text = read_raw_text("The_Winters_Tale.txt")
The_Merchent_of_Venice_raw_text = read_raw_text("The_Merchent_of_Venice.txt")
A_Midsummer_Nights_Dream_raw_text = read_raw_text("A_Midsummer_Nights_Dream.txt")

The_Merry_Wives_of_Windsor_raw_text = read_raw_text("The_Merry_Wives_of_Windsor.txt")
King_Henry_IV_Part_1_raw_text = read_raw_text("King_Henry_IV_Part_1.txt")
The_Comedy_of_Errors_raw_text = read_raw_text("The_Comedy_of_Errors.txt")
Titus_Andronicus_raw_text = read_raw_text("Titus_Andronicus.txt")

Cymbeline_raw_text = read_raw_text("Cymbeline.txt")
Timon_of_Athens_raw_text = read_raw_text("Timon_of_Athens.txt")
King_Richard_III_raw_text = read_raw_text("King_Richard_III.txt")
Coriolanus_raw_text = read_raw_text("Coriolanus.txt")

Alls_Well_That_Ends_Well_raw_text = read_raw_text("Alls_Well_That_Ends_Well.txt")
The_Two_Noble_Kinsmen_raw_text = read_raw_text("The_Two_Noble_Kinsmen.txt")
Pericles_Prince_of_Tyre_raw_text = read_raw_text("Pericles_Prince_of_Tyre.txt")
As_You_Like_It_raw_text = read_raw_text("As_You_Like_It.txt")

Loves_Labours_Lost_raw_text = read_raw_text("Loves_Labours_Lost.txt")
The_Tempest_raw_text = read_raw_text("The_Tempest.txt")
The_Two_Gentlemen_of_Verona_raw_text = read_raw_text("The_Two_Gentlemen_of_Verona.txt")
Timon_of_Athens_raw_text = read_raw_text("Timon_of_Athens.txt")

Titus_Andronicus_raw_text = read_raw_text("Titus_Andronicus.txt")
Troilus_and_Cressida_raw_text = read_raw_text("Troilus_and_Cressida.txt")

# %%
#Helper Functions

# %%
#takes in a string of text (a Shakespeor from Guttentberg) and returns a dictionary with {scene_name: text}
#For example return_var["much_ado_about_nothing_act2scene2"]="Enter Don John and Borach..."]
#Input must be in traditional format of including scene names at the top in a table of contents
def scene_breakout_scenes(raw_text_file, story_name):
    
    #stores scene name in list with each element tuple of structure 
    # ("Act III", "Scene IV.", "Another room in the Castle")
    contents_location=raw_text_file.find("Contents")

    #remove text prior to contents
    raw_text_file=raw_text_file[contents_location:]

    current_act="ACT 0"
    current_scene="SCENE 0."

    scene_name_list=[]

    #loop through contents lines storing scene names in scene_name_list
    #removes each line from raw_text_file after parsed
    while(raw_text_file.find("\n\n\n\n")>0):        
        new_line_loc = raw_text_file.find("\n")
        current_line=raw_text_file[0:new_line_loc]
        raw_text_file=raw_text_file[new_line_loc+1:]

        if current_line[:5]==" ACT " or current_line[:4]=="ACT ":
            start_loc = (1 if current_line[0]==" " else 0) #deals with that sometimes there is a space before the "act"
            current_act=current_line[start_loc:]
            current_scene=0

        elif current_line[:7]==" Scene " or current_line[:6]=="Scene ":
            dot_location = current_line.find(".")
            start_loc = (1 if current_line[:7]==" Scene " else 0) #deals with that sometimes there is a space before the "scene"
            current_scene=current_line[start_loc:dot_location]
            scene_name=current_act+"-"+current_scene+"-"+current_line[dot_location+2:]
            scene_name_list.append(scene_name)
            #scene_name now is a string that looks like ACT II-Scene I-A room in Polonius’s house
            
    
    scene_start_loc_list=[]

    #poplulate scene_start_loc_list with where each of the scene starts 
    for i in range(len(scene_name_list)):
        first_dash=scene_name_list[i].find("-")
        second_dash=scene_name_list[i][first_dash+1:].find("-")+first_dash+1
        
        #find the next scene in the text
        scene_name = scene_name_list[i][first_dash+1:second_dash].upper()+". "+scene_name_list[i][second_dash+1:]
        if i==0:
            scene_start_loc = raw_text_file.find(scene_name)
        else:
            last_start_loc=scene_start_loc_list[i-1]
            scene_start_loc = raw_text_file[last_start_loc:].find(scene_name)+last_start_loc
        scene_start_loc_list.append(scene_start_loc)

    #add end of book to scene_start_loc_list
    scene_start_loc_list.append(raw_text_file.find("*** END OF THE PROJECT GUTENBERG"))

    return_dict={} #will take form {scene_name: text}
    for i in range(len(scene_name_list)):
        start_loc = scene_start_loc_list[i] #start location of scene inclcuding scene title
        start_loc_no_title = raw_text_file.find("\n",start_loc)

        end_loc = scene_start_loc_list[i+1]
        
        scene_text=raw_text_file[start_loc_no_title:end_loc]
        return_dict[story_name+"-"+scene_name_list[i]] = scene_text

    return return_dict

# %%
scene_dict_Romeo_and_Juliet = scene_breakout_scenes(Romeo_and_Juliet_raw_text, "Romeo_and_Juliet") 
print(scene_dict_Romeo_and_Juliet.keys())
# Out:
# dict_keys(['Romeo_and_Juliet-ACT I-Scene I-A public place.', 'Romeo_and_Juliet-ACT I-Scene II-A Street.', 'Romeo_and_Juliet-ACT I-Scene III-Room in Capulet’s House.', 'Romeo_and_Juliet-ACT I-Scene IV-A Street.', 'Romeo_and_Juliet-ACT I-Scene V-A Hall in Capulet’s House.', 'Romeo_and_Juliet-ACT II-Scene I-An open place adjoining Capulet’s Garden.', 'Romeo_and_Juliet-ACT II-Scene II-Capulet’s Garden.', 'Romeo_and_Juliet-ACT II-Scene III-Friar Lawrence’s Cell.', 'Romeo_and_Juliet-ACT II-Scene IV-A Street.', 'Romeo_and_Juliet-ACT II-Scene V-Capulet’s Garden.', 'Romeo_and_Juliet-ACT II-Scene VI-Friar Lawrence’s Cell.', 'Romeo_and_Juliet-ACT III-Scene I-A public Place.', 'Romeo_and_Juliet-ACT III-Scene II-A Room in Capulet’s House.', 'Romeo_and_Juliet-ACT III-Scene III-Friar Lawrence’s cell.', 'Romeo_and_Juliet-ACT III-Scene IV-A Room in Capulet’s House.', 'Romeo_and_Juliet-ACT III-Scene V-An open Gallery to Juliet’s Chamber, overlooking the Garden.', 'Romeo_and_Juliet-ACT IV-Scene I-Friar
# ...

# %%
#Makes dictionarys of each of the text files

#works with format above
scene_dict_hamlet = scene_breakout_scenes(hamlet_raw_text, "Hamlet")
scene_dict_Julius_Caesar = scene_breakout_scenes(Julius_Caesar_raw_text, "Julius_Caesar")
scene_dict_The_Taming_Of_The_Shrew = scene_breakout_scenes(The_Taming_Of_The_Shrew_raw_text, "The_Taming_Of_The_Shrew")

scene_dict_Othello = scene_breakout_scenes(Othello_raw_text, "Othello")
scene_dict_Romeo_and_Juliet = scene_breakout_scenes(Romeo_and_Juliet_raw_text, "Romeo_and_Juliet")
scene_dict_Twelfth_Night = scene_breakout_scenes(Twelfth_Night_raw_text, "Twelfth_Night") 
scene_dict_King_Lear = scene_breakout_scenes(King_Lear_raw_text, "King_Lear") 

scene_dict_The_Winters_Tale = scene_breakout_scenes(The_Winters_Tale_raw_text, "The_Winters_Tale") 
scene_dict_The_Merchent_of_Venice = scene_breakout_scenes(The_Merchent_of_Venice_raw_text, "The_Merchent_of_Venice") 
scene_dict_A_Midsummer_Nights_Dream = scene_breakout_scenes(A_Midsummer_Nights_Dream_raw_text, "A_Midsummer_Nights_Dream") 

scene_dict_The_Merry_Wives_of_Windsor = scene_breakout_scenes(The_Merry_Wives_of_Windsor_raw_text, "The_Merry_Wives_of_Windsor")
scene_dict_King_Henry_IV_Part_1 = scene_breakout_scenes(King_Henry_IV_Part_1_raw_text, "King_Henry_IV_Part_1")
scene_dict_The_Comedy_of_Errors = scene_breakout_scenes(The_Comedy_of_Errors_raw_text, "The_Comedy_of_Errors")
scene_dict_Titus_Andronicus = scene_breakout_scenes(Titus_Andronicus_raw_text, "Titus_Andronicus")

scene_dict_Cymbeline = scene_breakout_scenes(Cymbeline_raw_text, "Cymbeline")
scene_dict_Timon_of_Athens = scene_breakout_scenes(Timon_of_Athens_raw_text, "Timon_of_Athens") 
scene_dict_King_Richard_III = scene_breakout_scenes(King_Richard_III_raw_text, "King_Richard_III")
scene_dict_Coriolanus = scene_breakout_scenes(Coriolanus_raw_text, "Coriolanus")

scene_dict_Alls_Well_That_Ends_Well = scene_breakout_scenes(Alls_Well_That_Ends_Well_raw_text, "Alls_Well_That_Ends_Well")
scene_dict_The_Two_Noble_Kinsmen = scene_breakout_scenes(The_Two_Noble_Kinsmen_raw_text, "The_Two_Noble_Kinsmen")
scene_dict_Pericles_Prince_of_Tyre = scene_breakout_scenes(Pericles_Prince_of_Tyre_raw_text, "Pericles_Prince_of_Tyre")
scene_dict_As_You_Like_It = scene_breakout_scenes(As_You_Like_It_raw_text, "As_You_Like_It")

scene_dict_Loves_Labours_Lost = scene_breakout_scenes(Loves_Labours_Lost_raw_text, "Loves_Labours_Lost")
scene_dict_The_Tempest = scene_breakout_scenes(The_Tempest_raw_text, "The_Tempest")
scene_dict_The_Two_Gentlemen_of_Verona = scene_breakout_scenes(The_Two_Gentlemen_of_Verona_raw_text, "The_Two_Gentlemen_of_Verona")
scene_dict_Timon_of_Athens = scene_breakout_scenes(Timon_of_Athens_raw_text, "Timon_of_Athens")

scene_dict_Titus_Andronicus = scene_breakout_scenes(Titus_Andronicus_raw_text, "Titus_Andronicus")
scene_dict_Troilus_and_Cressida = scene_breakout_scenes(Troilus_and_Cressida_raw_text, "Troilus_and_Cressida")

# %%
#Puts each dictionary into a list
all_scenes=[scene_dict_hamlet
            ,scene_dict_Julius_Caesar
            ,scene_dict_The_Taming_Of_The_Shrew 
            ,scene_dict_Othello
            ,scene_dict_Romeo_and_Juliet 
            ,scene_dict_Twelfth_Night
            ,scene_dict_King_Lear
            ,scene_dict_The_Winters_Tale 
            ,scene_dict_The_Merchent_of_Venice 
            ,scene_dict_A_Midsummer_Nights_Dream
            ,scene_dict_The_Merry_Wives_of_Windsor
            ,scene_dict_King_Henry_IV_Part_1
            ,scene_dict_The_Comedy_of_Errors
            ,scene_dict_Titus_Andronicus
            ,scene_dict_Cymbeline
            ,scene_dict_Timon_of_Athens
            ,scene_dict_King_Richard_III
            ,scene_dict_Coriolanus
            ,scene_dict_Alls_Well_That_Ends_Well
            ,scene_dict_The_Two_Noble_Kinsmen
            ,scene_dict_Pericles_Prince_of_Tyre
            ,scene_dict_As_You_Like_It
            ,scene_dict_Loves_Labours_Lost
            ,scene_dict_The_Tempest
            ,scene_dict_The_Two_Gentlemen_of_Verona
            ,scene_dict_Timon_of_Athens
            ,scene_dict_Titus_Andronicus
            ,scene_dict_Troilus_and_Cressida
]

# %%
#gets count of total scenes
count=0
for e in all_scenes:
    scenes=len(e.keys())
    print(scenes)
    count+=scenes
print("Total: ",count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #gets count of total scenes
#       2 count=0
# ----> 3 for e in all_scenes:
#       4     scenes=len(e.keys())
#       5     print(scenes)
#
# NameError: name 'all_scenes' is not defined
