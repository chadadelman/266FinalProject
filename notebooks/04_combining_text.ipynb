# %%
# %store -r all_scenes
# %store -r sonnets_dict
# %store -r jonson_scene_dict


all_text_dict={}
all_text_dict.update(all_scenes)
all_text_dict.update(sonnets_dict)
all_text_dict.update(jonson_scene_dict)

# %%
list(all_text_dict.keys())[123:134]
# Out:
# ['Coriolanus-ACT V-Scene V-Rome. A street near the gate',
#  'Coriolanus-ACT V-Scene VI-Antium. A public place',
#  'Cymbeline-ACT I-Scene I-Britain. The garden of Cymbeline’s palace.',
#  'Cymbeline-ACT I-Scene II-The same.',
#  'Cymbeline-ACT I-Scene III-Britain. A public place.',
#  'Cymbeline-ACT I-Scene IV-Britain. Cymbeline’s palace.',
#  'Cymbeline-ACT I-Scene V-Rome. Philario’s house.',
#  'Cymbeline-ACT I-Scene VI-Britain. Cymbeline’s palace.',
#  'Cymbeline-ACT I-Scene VII-Britain. The palace.',
#  'Cymbeline-ACT II-Scene I-Britain. Before Cymbeline’s palace.',
#  'Cymbeline-ACT II-Scene II-Britain. Imogen’s bedchamber in Cymbeline’s palace; a trunk']
