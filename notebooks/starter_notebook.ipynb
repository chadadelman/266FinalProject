# %%
search_list = ["apple", "banana", "cherry"]
main_string = "I love eating a delicious banana."

if any(item in main_string for item in search_list):
    print("At least one string from the list is found in the main string.")
else:
    print("No strings from the list are found in the main string.")
# Out:
# At least one string from the list is found in the main string.
