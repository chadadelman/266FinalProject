# %%
# %store -r test_paired_summaries

# %%
#Creating full test list for running the model
test_full_list = list()
for v in test_paired_summaries.values():
    test_full_list.append(v[0])

# %%
#Looking at data
print(type(test_full_list))
print(len(test_full_list))
#print(test_full_list[0])
# Out:
# <class 'list'>
# 141

# %%
#Pull model
#this is final validation model (model 4) even though I didnt name it as such... messup on my part, code still works but more confusing
# %store -r train_model_config_1
# Out:
# /Users/chadadelman/anaconda3/envs/chad_env/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import torch
from torch.utils.data import DataLoader

def run_model(model
              ,tokenizer
              ,device
              ,test_text_list
              ,max_length = 32
              ,num_beams = 2):
    
    generated_text_list=[]

    for test_text in test_text_list:
        #summarize each item in test_text_list
        inputs = tokenizer(
            "summarize: " + test_text,
            return_tensors="pt",
            truncation=True,
            padding=True,
        ).to(device)

        with torch.no_grad():
            generated_ids = model.generate(
                **inputs,
                max_length=max_length,
                num_beams=num_beams,
            )

        generated_text = tokenizer.decode(generated_ids[0], skip_special_tokens=True)
        generated_text_list.append(generated_text)
    
    return generated_text_list

# %%
#Run model with config 1 from first validation
generated_full_test_list = run_model(model = train_model_config_1[0]
                    ,tokenizer = train_model_config_1[1]
                    ,device = train_model_config_1[2]
                    ,test_text_list = test_full_list
                    ,max_length = 48
                    ,num_beams = 6)

# %%
#Examining results 
print(type(generated_full_test_list))
print(len(generated_full_test_list))
print()

print(generated_full_test_list[0])
print(generated_full_test_list[5])
print(generated_full_test_list[23])
print(generated_full_test_list[29])
print(generated_full_test_list[135])
# Out:
# <class 'list'>
# 141
#
# Flavius, Marullus, and a throng of Citizens gather to discuss their relationship with Flavius. Flavius reveals that Flavius is a cobbler, but Flavius refuse
# Artemidorus tries to convince Casca that Brutus is a victim of emulation. Casca tries to convince him that Brutus is a victim of emulation
# Donalbain, Banquo, Lennox, Ross, Angus and Macduff attend the castle. Banquo and Lennox reaffirm their admiration for Macbeth’s love. The
# Banquo attends a solemn supper with Lennox, Ross, Lords, and Attendants. Lennox, Ross, Ross, Ross, Ross, Ross, Ross, Ross, Ross, and
# The two lovers have of comfort and despair, which suggest me still: The better angel is a man right fair, The worser spirit a woman coloured ill. To win me soon to hell, my female evil,

# %%
# %store generated_full_test_list
# Out:
# Stored 'generated_full_test_list' (list)
