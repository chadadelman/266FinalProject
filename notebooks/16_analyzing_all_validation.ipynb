# %%
# %store -r generated_full_val_list
#string of summaries on t5 model for all validatios

# %%
# %store -r val_paired_summaries
#dict with Key is scene and Value as tupple (text, summary, human-made-flag)

# %%
#Looking up scene by number
print(list(val_paired_summaries.keys())[0]) #Hamlet-Act I-Scene I
print(list(val_paired_summaries.keys())[113]) #Sonnet 109
# Out:
# Hamlet-Act I-Scene I
# Sonnet 109

# %%
#Looking at tuned T5 genertaed results
print(generated_full_val_list[0]) #Hamlet-Act I-Scene I
print(generated_full_val_list[113]) #Sonnet 109
# Out:
# Francisco and Barnardo, both sentinels, await their arrival. Barnardo and Horatio await their return to the Dane. They await their return to the Dane, believing he is in danger. The
# False of heart, but he refuses to return to his home of love. False of heart, he refuses to return to his home of love. False of heart, he refuses

# %%
#Looking at human results
print(list(val_paired_summaries.values())[0][1]) #Hamlet-Act I-Scene I
print(list(val_paired_summaries.values())[113][1])  #Sonnet 109
# Out:
# The Ghost of Hamlet's father appears to Horatio and two sentinels. They wonder what it portends and decide that Hamlet should be told.
# The poet defends his infidelities, arguing that his return washes away the blemish of his having left.

# %%
from rouge_score import rouge_scorer
from bert_score import score as bertscore

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

import numpy as np

from bert_score import score as bertscore

import torch

from transformers import AutoModel
# Out:
# /Users/chadadelman/anaconda3/envs/chad_env/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
#similarity methods functions (made with help of ChatGPT)
def compute_rouge(text1, text2):
    """
    Compute ROUGE between two texts.
    Returns F1 scores for ROUGE-1, ROUGE-2, ROUGE-L.
    """
    scorer = rouge_scorer.RougeScorer(
        ['rouge1', 'rouge2', 'rougeL'],
        use_stemmer=True
    )
    # Note: scorer.score(reference, prediction)
    scores = scorer.score(text2, text1)

    return {
        "rouge1": scores["rouge1"].fmeasure,
        "rouge2": scores["rouge2"].fmeasure,
        "rougeL": scores["rougeL"].fmeasure,
    }


def compute_cosine_similarity(text1, text2):
    """
    Compute cosine similarity between two texts using TF-IDF vectors.
    This avoids loading any transformer model and is stable in most environments.
    """
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform([text1, text2])  # shape (2, vocab_size)

    cos_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])  # (1,1)
    return float(cos_sim[0, 0])

def compute_bertscore(text1: str, text2: str):
    """
    Compute BERTScore (Precision, Recall, F1) between two texts.
    text1 = candidate
    text2 = reference
    """
    P, R, F1 = bertscore(
        cands=[text1],
        refs=[text2],
        lang="en"
    )
    return {
        "precision": float(P[0]),
        "recall": float(R[0]),
        "f1": float(F1[0]),
    }

# %%
rouge_score_list_all_val=[]
cosine_score_list_all_val=[]
bertscore_list_all_val=[]

#Scoring average results vs the human anwers in all metrics 
for i in range(len(generated_full_val_list)):
    t5_summary = generated_full_val_list[i]
    human_summary = list(val_paired_summaries.values())[i][1]
    
    rouge_score_list_all_val.append(compute_rouge(t5_summary, human_summary))
    cosine_score_list_all_val.append(compute_cosine_similarity(t5_summary, human_summary))
    bertscore_list_all_val.append(compute_bertscore(t5_summary, human_summary))
    
    if i%10==0:
        print(i)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...

# %%
# %store rouge_score_list_all_val
# %store cosine_score_list_all_val
# %store bertscore_list_all_val
# Out:
# Stored 'rouge_score_list_all_val' (list)
# Stored 'cosine_score_list_all_val' (list)
# Stored 'bertscore_list_all_val' (list)

# %%
#Looking at data
print(rouge_score_list_all_val[0])
print(bertscore_list_all_val[0])
# Out:
# {'rouge1': 0.2592592592592593, 'rouge2': 0.0, 'rougeL': 0.11111111111111112}
# {'precision': 0.8633716106414795, 'recall': 0.8554269075393677, 'f1': 0.8593809008598328}

# %%
#Compute averages across all validation dataset
rouge_score_list_all_val_avg = [0,0,0]
cosine_score_list_all_val_avg = 0
bertscore_list_all_val_avg = [0,0,0]

passage_count=len(rouge_score_list_all_val)

for i in range(passage_count):
    rouge_score_list_all_val_avg[0] += rouge_score_list_all_val[i]["rouge1"]
    rouge_score_list_all_val_avg[1] += rouge_score_list_all_val[i]["rouge2"]
    rouge_score_list_all_val_avg[2] += rouge_score_list_all_val[i]["rougeL"]
    cosine_score_list_all_val_avg += cosine_score_list_all_val[i]
    bertscore_list_all_val_avg[0] += bertscore_list_all_val[i]["precision"]
    bertscore_list_all_val_avg[1] += bertscore_list_all_val[i]["recall"]
    bertscore_list_all_val_avg[2] += bertscore_list_all_val[i]["f1"]

rouge_score_list_all_val_avg[0] /=passage_count
rouge_score_list_all_val_avg[1] /=passage_count
rouge_score_list_all_val_avg[2] /=passage_count
cosine_score_list_all_val_avg /=passage_count
bertscore_list_all_val_avg[0] /=passage_count
bertscore_list_all_val_avg[1] /=passage_count
bertscore_list_all_val_avg[2] /=passage_count

# %%
print(rouge_score_list_all_val_avg)
print(cosine_score_list_all_val_avg)
print(bertscore_list_all_val_avg)
# Out:
# [0.18695062554044056, 0.019588477159987554, 0.13902957117274728]
# 0.18546962869084552
# [0.8363514910725987, 0.8338364564320621, 0.8348533195607802]
